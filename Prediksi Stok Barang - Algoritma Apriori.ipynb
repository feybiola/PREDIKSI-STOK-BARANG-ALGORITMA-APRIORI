# %%
# Menginstall Library
# !pip install pandas
# !pip install numpy
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=9a58f56ed4b20883169deb5942583690ea54c0ef52ad73b16cbe7498211f1e12
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Memanggil library yang dibutuhkan
import pandas as pd
import numpy as np
from apyori import apriori

# %%
# Loading the Data
df= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Dataset_Penjualan_15-11-2021.xlsx')
df.head()
# Out:
#      Tanggal ID Transaksi                                              Items
# 0 2021-11-15      AL01013                             Good Day Special 35 Gr
# 1 2021-11-15      AL01014  KERTAS FOLIO, ABC SAMBAL SAOS MEJA, Citra Beng...
# 2 2021-11-15      AL01015  BANGO 1000, Pepsodent 120 gr, Zinc Shampo sach...
# 3 2021-11-15      AL01016  ABC Terasi Sach, Citra Sabun, Dove sha sach, B...
# 4 2021-11-15      AL01017  Buku Gambar A4 Ria, KERTAS FOLIO, KERTAS FOLIO...

# %%
# Membuang kolom Tanggal, ID Transaksi
data=df.drop(['Tanggal', 'ID Transaksi'],axis=1)

# %%
# Membuat list dalam list dari transaksi pembelian barang
records = []
for i in range(data.shape[0]):
    records.append([str(data.values[i,j]).split(',') for j in range(data.shape[1])])

trx = [[] for trx in range(len(records))]
for i in range(len(records)):
    for j in records[i][0]:
        trx[i].append(j)
trx
# Out:
# [['Good Day Special 35 Gr'],
#  ['KERTAS FOLIO',
#   ' ABC SAMBAL SAOS MEJA',
#   ' Citra Bengkoang Sach',
#   ' Daia 1000',
#   ' MAMA LIME 160 ML',
#   ' Zinc Shampo sach',
#   ' Beng-Beng 20 Gr',
#   ' Beng-beng 20gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Hello Panda',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   '  LPG 12kg'],
#  ['BANGO 1000',
#   ' Pepsodent 120 gr',
#   ' Zinc Shampo sach',
#   ' Zinc Shampo sach',
#   ' Kwaci Bunga Matahari',
#   ' LPG 3kg'],
#  ['ABC Terasi Sach',
#   ' Citra Sabun',
#   ' Dove sha sach',
#   ' Biskuat Bolu',
#   ' Biskuat Bolu',
#   ' Biskuat Bolu',
#   ' Biskuat Bolu',
#   ' Biskuat Bolu',
#   ' Beng-Beng 20 Gr',
#   ' Gery Donouts',
#   ' Kwaci Bunga Matahari'],
#  ['Buku Gambar A4 Ria',
#   ' KERTAS FOLIO',
#   ' KERTAS FOLIO',
#   ' ABC Terasi Sach',
#   ' ABC Terasi Sach',
#   ' ABC KECAP BOTOL 135ML',
#   ' Rinso 500',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Kopiko',
#   ' Marely Milk Meises',
#   ' LPG 12kg'],
#  ['Daia 1000',
#   ' Formula SIkat Gigi',
#   ' Biskuat Bolu',
#   ' Fullo',
#   ' Kopiko',
#   'Kopiko',
#   ' Oreo',
#   ' Oreo',
#   ' Oreo'],
#  ['Buku Gambar A4 Ria',
#   ' KERTAS KADO',
#   ' Serutan kotak',
#   ' ABC SAMBAL SAOS MEJA',
#   ' Bango kecap reff 600',
#   ' BANGO 1000',
#   ' Ciptadent 75 gr',
#   ' Daia 1000',
#   ' Formula SIkat Gigi',
#   ' Biskuat Bolu',
#   ' Relaxa',
#   ' LPG 3kg'],
#  ['Good Day Special 35 Gr',
#   ' BANGO 1000',
#   ' BANGO 1000',
#   ' BANGO 1000',
#   ' BANGO 1000',
#   ' LPG 12kg'],
#  ['Shinzui Sabun',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Kwaci Bunga Matahari',
#   ' LPG 12kg'],
#  ['ABC Terasi Sach',
#   ' Ekonomi EK 200',
#   ' Chi-Cho',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari'],
#  ['LEM KERTAS',
#   ' MAMA LIME 160 ML',
#   ' Shinzui Sabun',
#   ' Beng-Beng 20 Gr',
#   ' Hello Panda',
#   ' Hello Panda '],
#  ['KERTAS FOLIO',
#   ' MAMA LIME 160 ML',
#   ' Beng-Beng 20 Gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Gery Donouts',
#   ' Gery Donouts',
#   ' Gery Donouts',
#   'Kwaci Bunga Matahari',
#   ' LPG 3kg'],
#  ['KERTAS FOLIO',
#   ' ABC KECAP BOTOL 135ML',
#   ' Biskuat Bolu',
#   ' Beng-Beng 20 Gr',
#   ' Gery Donouts',
#   ' Hello Panda'],
#  ['KERTAS FOLIO',
#   ' Bango kecap reff 600',
#   ' Good Day Special 35 Gr',
#   ' Beng-Beng 20 Gr',
#   ' Kopiko',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari',
#   ' Kwaci Bunga Matahari'],
#  ['Bango kecap reff 600',
#   ' BANGO 1000',
#   ' Emeron sha 100 ml',
#   ' Biskuat Energi 22.5 Gr',
#   ' Fullo',
#   ' Gery Donouts',
#   '  Hello Panda',
#   ' Kopiko',
#   ' Marely Milk Meises',
#   ' LPG 12kg'],
#  ['KERTAS FOLIO',
#   ' Downy Sach',
#   ' Biskuat Energi 22.5 Gr',
#   ' Fullo',
#   ' Kopiko',
#   ' LPG 3kg'],
#  ['Fullo', ' Kopiko', ' Kopiko', ' Kopiko', ' Chi-Cho', ' Chi-Cho'],
#  ['KERTAS KADO', ' Citra Sabun', ' Biskuat Bolu', ' Jetz'],
#  ['Daia 1000',
#   ' Pepsodent 120 gr',
#   ' Zinc Shampo sach',
#   ' Biskuat Bolu',
#   ' Beng-Beng 20 Gr',
#   ' LPG 12kg'],
#  ['KERTAS FOLIO',
#   ' ABC KECAP BOTOL 135ML',
#   ' Biskuat Bolu',
#   ' Ballet Twist',
#   ' Fullo',
#   ' Relaxa',
#   ' LPG 12kg',
#   ' '],
#  ['ABC SAMBAL SAOS MEJA',
#   ' Citra Bengkoang Sach',
#   ' Biskuat Bolu',
#   ' Beng-Beng 20 Gr',
#   ' Gery Donouts',
#   ' Kwaci Bunga Matahari',
#   ' Oreo'],
#  ['Buku Gambar A4 Ria',
#   ' Dove sha sach',
#   ' Chi-Cho',
#   ' Gery Donouts',
#   ' Hello Panda',
#   ' Kopiko',
#   ' Kwaci Bunga Matahari',
#   ' French Fries'],
#  ['ABC SARDEN 155 Gr',
#   ' Dove sha sach',
#   ' MAMA LIME 160 ML',
#   ' Zinc Shampo sach',
#   ' Biskuat Energi 22.5 Gr',
#   ' Kwaci Bunga Matahari',
#   ' LPG 3kg'],
#  [' Serutan kotak',
#   ' Downy Sach',
#   ' Biskuat Bolu',
#   ' Beng-Beng 20 Gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Hello Panda'],
#  ['Bango kecap reff 600', ' Ekonomi EK 200', ' Kacang Garing 500'],
#  ['Makaroni', ' Makaroni', ' LPG 3kg'],
#  ['Carrera Shampo Motor', ' Padimas Bolu', ' LPG 3kg'],
#  ['TBM',
#   ' Dove sha sach',
#   ' Zinc Shampo sach',
#   ' Beng-Beng 20 Gr',
#   ' Chi-Cho',
#   ' LPG 12kg'],
#  ['KERTAS FOLIO', ' Citra Sabun', ' Emeron sha 100 ml', ' Emeron sha 100 ml'],
#  ['Citra Bengkoang Sach',
#   ' Rinso 500',
#   ' Hello Panda',
#   ' Hello Panda',
#   ' Hello Panda',
#   ' Hello Panda',
#   ' Hello Panda',
#   ' Hello Panda'],
#  ['BANGO 1000', ' Daia 900 Gr', ' Biskuat Bolu', ' Kacang Garing 500'],
#  ['KERTAS KADO',
#   ' Citra Sabun',
#   ' Citra Sabun',
#   ' Ciptadent 75 gr',
#   ' Shinzui Sabun',
#   ' Chi-Cho'],
#  ['KERTAS KADO',
#   ' UNISTAR 28',
#   ' Downy Sach',
#   ' MAMA LIME 160 ML',
#   ' Rinso Cair',
#   ' Biskuat Energi 22.5 Gr',
#   ' Marely Milk Meises'],
#  ['ABC SAMBAL SAOS MEJA',
#   ' Vanili R',
#   ' Downy Sach',
#   ' Shinzui Sabun',
#   ' Shinzui Sabun',
#   ' Shinzui Sabun',
#   ' Biskuat Energi 22.5 Gr'],
#  ['Formula SIkat Gigi',
#   ' Formula SIkat Gigi',
#   ' Formula SIkat Gigi',
#   ' Rexona Man Sach',
#   ' Gery Donouts'],
#  ['ABC Terasi Sach',
#   ' Pepsodent 120 gr',
#   ' Biskuat Energi 22.5 Gr',
#   ' Fullo',
#   ' KejuCake',
#   ' KejuCake',
#   ' KejuCake'],
#  ['UNISTAR 28',
#   ' Good Day Special 35 Gr',
#   ' MAMA LIME 160 ML',
#   ' Fullo',
#   ' Gery Donouts'],
#  ['Dove sha sach',
#   ' Biskuat Bolu',
#   ' Fullo',
#   ' Gery Donouts',
#   ' French Fries',
#   ' French Fries',
#   ' French Fries'],
#  ['Aroma Pasta 30 ML', ' Fullo', ' Kopiko', ' Kopiko', ' Kopiko'],
#  ['Soklin Lantai Sach', ' Biskuat Energi 22.5 Gr', ' Oreo'],
#  ['Daia 1000', ' Daia 1000', ' Biskuat Energi 22.5 Gr', ' Fullo', ' LPG 12kg'],
#  ['Beng-Beng 20 Gr', ' Hello Panda', ' Hello Panda', ' Hello Panda'],
#  ['Buku Tulis Big Boss 42 Lembar', ' UNISTAR 28'],
#  ['FABER CASTEL 2B', ' UNISTAR 28', ' Pepsodent 120 gr', ' Chi-Cho'],
#  ['KERTAS FOLIO',
#   ' ABC SAMBAL SAOS MEJA',
#   '  ABC SAMBAL SAOS MEJA',
#   ' BANGO 1000',
#   ' BANGO 1000',
#   ' Citra Bengkoang Sach',
#   ' Fullo',
#   ' Fullo',
#   ' Fullo',
#   ' Kwaci Bunga Matahari',
#   ' LPG 3kg']]

# %%
# Menggunakan fungsi apriori untuk membuat asosiasi
association_rules = apriori(trx, min_support=0.1, min_confidence=0.3,min_lift=1)
# Membuat list hasil dari algoritma apriori
association_results = association_rules

# %%
# Menampilkan hasil asosiasi dari item 
pd.set_option('max_colwidth', 1000)
Result=pd.DataFrame(columns=['Rule','Support','Confidence'])
for item in association_results:
    pair = item[2]
    for i in pair:
        items = str([x for x in i[0]])
        if i[3]!=1:
            Result=Result.append({
                'Rule':str([x for x in i[0]])+ " -> " +str([x for x in i[1]]),
                'Support':str(round(item[1]*100,2))+'%',
                'Confidence':str(round(i[2] *100,2))+'%'
                },ignore_index=True)
Result
# Out:
#                                                 Rule Support Confidence
# 0          [' Beng-Beng 20 Gr'] -> [' Biskuat Bolu']  11.11%     41.67%
# 1          [' Biskuat Bolu'] -> [' Beng-Beng 20 Gr']  11.11%     45.45%
# 2  [' Beng-Beng 20 Gr'] -> [' Kwaci Bunga Matahari']  11.11%     41.67%
# 3  [' Kwaci Bunga Matahari'] -> [' Beng-Beng 20 Gr']  11.11%      50.0%
